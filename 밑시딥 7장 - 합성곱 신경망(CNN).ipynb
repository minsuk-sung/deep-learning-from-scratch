# %% [markdown]
# ![밑시딥 교재](http://www.hanbit.co.kr/data/books/B8475831198_l.jpg)
#
# > 작성자 : [Minsuk Sung](https://github.com/mssung94)
# > 연락처 : mssung94@gmail.com
# > GitHub : https://github.com/mssung94
#
# > 본 내용은 **대학생 빅데이터 동아리 `BOAZ`의 딥러닝 스터디 자료**입니다. **상업적인 목적으로 사용하는 것은 절대로 금합니다.**
#
# > 모든 내용은 `밑바닥부터 시작하는 딥러닝(Deep Learning from Scratch),한빛미디어`을 참고하여 만들어졌으며, 책의 내용에 대한 모든 저작권은 `한빛미디어`에게 있음을 미리 밝힙니다. 또한 여기에 사용된 코드의 대부분은 한빛미디어에서 제공해준 GitHub을 바탕으로 재구성하였습니다.
#
# 한빛미디어 홈페이지 : http://www.hanbit.co.kr/store/books/look.php?p_code=B8475831198
# 밑바닥부터 시작하는 딥러닝 GitHub : https://github.com/WegraLee/deep-learning-from-scratch

# %% [markdown]
# <h1>7장 합성곱 신경망 (CNN)<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#전체-구조-(p227)" data-toc-modified-id="전체-구조-(p227)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>전체 구조 (p227)</a></span></li><li><span><a href="#합성곱-계층-(p229)" data-toc-modified-id="합성곱-계층-(p229)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>합성곱 계층 (p229)</a></span><ul class="toc-item"><li><span><a href="#완전연결-계층의-문제점" data-toc-modified-id="완전연결-계층의-문제점-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>완전연결 계층의 문제점</a></span></li><li><span><a href="#합성곱-연산" data-toc-modified-id="합성곱-연산-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>합성곱 연산</a></span></li><li><span><a href="#패딩(Padding)" data-toc-modified-id="패딩(Padding)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>패딩(Padding)</a></span></li><li><span><a href="#스트라이드(Stride)" data-toc-modified-id="스트라이드(Stride)-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>스트라이드(Stride)</a></span></li><li><span><a href="#특징-맵의-크기-계산하기" data-toc-modified-id="특징-맵의-크기-계산하기-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>특징 맵의 크기 계산하기</a></span></li><li><span><a href="#3차원-데이터의-합성곱-연산" data-toc-modified-id="3차원-데이터의-합성곱-연산-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>3차원 데이터의 합성곱 연산</a></span></li><li><span><a href="#블록으로-생각하기-⇒-배치가-1일-때" data-toc-modified-id="블록으로-생각하기-⇒-배치가-1일-때-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>블록으로 생각하기 ⇒ 배치가 1일 때</a></span></li><li><span><a href="#배치처리" data-toc-modified-id="배치처리-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>배치처리</a></span></li></ul></li><li><span><a href="#풀링-계층-(p240)" data-toc-modified-id="풀링-계층-(p240)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>풀링 계층 (p240)</a></span><ul class="toc-item"><li><span><a href="#풀링-계층의-특징" data-toc-modified-id="풀링-계층의-특징-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>풀링 계층의 특징</a></span><ul class="toc-item"><li><span><a href="#학습해야-할-매개변수가-없다" data-toc-modified-id="학습해야-할-매개변수가-없다-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>학습해야 할 매개변수가 없다</a></span></li><li><span><a href="#채널-수가-변하지-않는다" data-toc-modified-id="채널-수가-변하지-않는다-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>채널 수가 변하지 않는다</a></span></li><li><span><a href="#입력의-변화에-영향을-적게-받는다(강건하다)" data-toc-modified-id="입력의-변화에-영향을-적게-받는다(강건하다)-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>입력의 변화에 영향을 적게 받는다(강건하다)</a></span></li></ul></li></ul></li><li><span><a href="#합성곱/풀링-계층-구현하기-(p242)" data-toc-modified-id="합성곱/풀링-계층-구현하기-(p242)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>합성곱/풀링 계층 구현하기 (p242)</a></span><ul class="toc-item"><li><span><a href="#4차원-배열" data-toc-modified-id="4차원-배열-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>4차원 배열</a></span></li><li><span><a href="#im2col로-데이터-전개하기" data-toc-modified-id="im2col로-데이터-전개하기-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>im2col로 데이터 전개하기</a></span></li><li><span><a href="#합성곱-계층-구현하기" data-toc-modified-id="합성곱-계층-구현하기-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>합성곱 계층 구현하기</a></span></li><li><span><a href="#풀링-계층-구현하기" data-toc-modified-id="풀링-계층-구현하기-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>풀링 계층 구현하기</a></span></li></ul></li><li><span><a href="#CNN-구현하기-(p250)" data-toc-modified-id="CNN-구현하기-(p250)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>CNN 구현하기 (p250)</a></span><ul class="toc-item"><li><span><a href="#SimpleConvNet으로-MNIST-데이터셋-학습하기" data-toc-modified-id="SimpleConvNet으로-MNIST-데이터셋-학습하기-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>SimpleConvNet으로 MNIST 데이터셋 학습하기</a></span></li></ul></li><li><span><a href="#CNN-시각화하기-(p254)" data-toc-modified-id="CNN-시각화하기-(p254)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>CNN 시각화하기 (p254)</a></span><ul class="toc-item"><li><span><a href="#첫번째-층의-가중치-시각화하기" data-toc-modified-id="첫번째-층의-가중치-시각화하기-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>첫번째 층의 가중치 시각화하기</a></span><ul class="toc-item"><li><span><a href="#MNIST-에서-학습한-필터-확인해보기" data-toc-modified-id="MNIST-에서-학습한-필터-확인해보기-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>MNIST 에서 학습한 필터 확인해보기</a></span></li><li><span><a href="#Lena-이미지로-필터-확인해보기" data-toc-modified-id="Lena-이미지로-필터-확인해보기-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Lena 이미지로 필터 확인해보기</a></span></li></ul></li><li><span><a href="#층-깊이에-따른-추출-정보-변화" data-toc-modified-id="층-깊이에-따른-추출-정보-변화-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>층 깊이에 따른 추출 정보 변화</a></span></li></ul></li><li><span><a href="#대표적인-CNN-(p257)" data-toc-modified-id="대표적인-CNN-(p257)-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>대표적인 CNN (p257)</a></span><ul class="toc-item"><li><span><a href="#LeNet" data-toc-modified-id="LeNet-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>LeNet</a></span></li><li><span><a href="#AlexNet" data-toc-modified-id="AlexNet-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>AlexNet</a></span></li></ul></li><li><span><a href="#7장-정리-(p259)" data-toc-modified-id="7장-정리-(p259)-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>7장 정리 (p259)</a></span></li><li><span><a href="#참고" data-toc-modified-id="참고-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>참고</a></span></li></ul></div>

# %% [markdown]
# > 내용 출처 : [WegraLee GitHub](https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch07/README.md)
#
# 이번 장의 주제는 합성곱 신경망(convolutional neural network, CNN)입니다. CNN은 이미지 인식과 음성 인식 등 다양한 곳에서 사용되는데, 특히 이미지 인식 분야에서 딥러닝을 활용한 기법은 거의 다 CNN을 기초로 하죠. 이번 장에서는 CNN의 메커니즘을 자세히 설명하고 이를 파이썬으로 구현해보겠습니다.
#
# *옮긴이_ 합성곱은 공학과 물리학에서 널리 쓰이는 수학적 개념으로, 간단히 정의해보면 다음과 같습니다.
# “두 함수 중 하나를 반전(reverse), 이동(shift)시켜가며 나머지 함수와의 곱을 연이어 적분한다.”
# 합성곱 신경망을 영어 발음 그대로 ‘컨벌루션 신경망’으로도 많이 씁니다만, 위 정의와 이번 장에서 설명할 동작 원리를 이해하고 나면 ‘합성곱 신경망’이란 용어가 더 직관적으로 다가올 수도 있을 겁니다.*

# %%
# coding: utf-8
import os
import sys
import pickle
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.image import imread
from collections import OrderedDict
from common.optimizer import *
from common.util import im2col,col2im
from common.layers import *
from common.gradient import numerical_gradient
from common.trainer import Trainer
from dataset.mnist import load_mnist

mpl.rcParams['font.family'] = 'AppleGothic' # mac에서는 한글이 나오게 하기 위해서
mpl.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ---
#
# ## 전체 구조 (p227)
#
# - 합성곱 계층(Convolutional Layer)
# - 풀링 계층(Pooling Layer)
# - 지금까지의 여러가지 신경망들과 동일하게 레고블록 조립하듯이 위 두 계층을 통해서 합성곱 신경망을 구성

# %% [markdown]
# - 지금까지 본 신경망은 인접하는 계층의 모든 뉴런과 결합되어 있었음 ⇒ 완전연결 계층(Fully Connected Layer), 어파인(Affine) 계층이라고 했었음
#
#
# > - Affine 계층만으로 이루어진 네트워크
# ![](https://t1.daumcdn.net/cfile/tistory/99AC8A4C5BA493CD17)
#
# > - **`합성곱 계층`** 과 **`풀링 계층`** 을 새로 추가한 네트워크
# ![](https://t1.daumcdn.net/cfile/tistory/9940853A5BA493CD24)

# %% [markdown]
# - 일반적인 CNN에서 흔히 볼 수 있는 구성
#     1. `Affine - ReLU` ⇒ `Conv - ReLU ( - Pooling )` 로 구성이 바뀌었다는 점
#     2. 출력에 가까운 층에서는 지금까지의 `Affine - ReLU` 조합을 사용할 수 있다는 점
#     3. 마지막 출력 계층에서는 `Affine - Softmax` 조합응ㄹ 그대로 사용한다는 점

# %% [markdown]
# ---
#
# ## 합성곱 계층 (p229)

# %% [markdown]
# ### 완전연결 계층의 문제점
#
# > 완전연결 계층의 문제점 : 데이터의 형상이 무시된다
#
# - **이미지(image)**는 보통 `세로 / 가로 / 채널(색상)` 으로 구성된 <b><font color='red'>3차원 데이터</font></b>
# - 완전연결 계층에 입력할 때는 이러한 3차원 데이터를 1차원 데이터로 평탄화(flatten)시켜야함
#     - MNIST를 예시로 들자면, $28\times28$인 데이터를 모두 1줄로 만들어서 $1 \times 784$ 인 데이터로 형상을 바꿔야 했음
# - 사실 이미지는 엄연히 3차원 데이터! 3차원 데이터 안에는 소중한 공간적 정보가 담겨있음!
#     - 공간적으로 가까운 픽셀은 값이 비슷
#     - RGB의 각 채널은 서로 밀접하게 관련
#     - 거리가 먼 픽셀끼리는 별 연관이 없음
# - 하지만, 완전연결 계층은 형상을 무시하고 모든 입력 데이터를 동등한 뉴런으로 취급하여 형상에 담긴 정보를 살릴 수 없음
#
# <img src="http://www.cs.cornell.edu/courses/cs1133/2015fa/assignments/assignment2/images/Barn_grand_tetons_rgb_separation.jpg" width="200"/>

# %% [markdown]
# - 합성곱 계층은 완전연결 계층과 달리 형상을 유지함
# - 입력으로 이미지 그 자체, 즉 3차원 데이터로 받으며, 다음 계층에도 3차원 데이터로 전달함
# - 그래서 합성곱 신경망은 이미지처럼 형상을 가진 데이터를 제대로 이해할 가능성이 높다

# %% [markdown]
# ### 합성곱 연산
#
# ![](https://blogfiles.pstatic.net/MjAxODA5MjRfMTIg/MDAxNTM3Nzc3MDA4MDcz.ZLS5VP1SzE08TSxlb1MnOrUZRoMvoXXo6TNVKBJ8kGgg.L86OQLSPnBP9SiixmuKhVvE_IPlueb9DEidBy9XSM3Ug.PNG.ssdyka/fig_7-3.png?type=w2)
#
# - 합성곱 연산은 입력 데이터에 필터(Filter) 혹은 커널(Kernel)을 적용
# - CNN에서는 합성곱 계층의 입출력 데이터를 특징 맵(Feature Map)이라고 함

# %% [markdown]
# - 합성곱 연산 과정
#     1. 합성곱 연산은 필터의 윈도우(window)를 일정 간격으로 이동해가며 입력 데이터에 적용
#     2. 입력과 필터에서 대응하는 원소끼리(pairwise) 곱한 후 (행렬의 곱셈이 아님!!) 그 총합을 구함
#     3. 그 결과를 출력의 해당 장소에 저장함
#
# ![](https://blogfiles.pstatic.net/MjAxODA5MjRfMjAx/MDAxNTM3Nzc3MDA4ODgx.1Q3ihW_JSVr3c1uO_Fid2l13VjON0TjcTBLR-5Sf15cg.IIhaKtgYwz20y-eX_rw2yuF67kQLhOui6xP4wfkbXNog.PNG.ssdyka/fig_7-4.png?type=w2)
#
# > 물론 완전계층에서의 가중치 매개변수와 편향과 같이 합성곱 계층에도 필터의 매개변수와 편향을 학습해야함
# > 참고로 편향은 출력 특징맵에 브로드캐스팅되어 모든 편향값을 더해주면 됨
#
# ![](https://blogfiles.pstatic.net/MjAxODA5MjRfNjEg/MDAxNTM3Nzc3MDA5NDQw.lH0Y9T-gJpLlB4ZMp695Jh0rtaJfMP81tDpCYSibhcwg.kRtwLNxXiT_LtfbnzcqG4dtHj0m85yYoJWJPLOLfeVQg.PNG.ssdyka/fig_7-5.png?type=w2)
#
# <br>
#
# <center> <font size = 5> 즉, CNN에서는 <font color = 'red'>필터의 매개변수</font>가<br>우리가 <font color = 'red'> 학습해야할 가중치</font>에 해당 </font> </center>

# %% [markdown]
# > 이미지가 움직이지 않는다면 : https://miro.medium.com/max/2340/1*Fw-ehcNBR9byHtho-Rxbtw.gif
#
# ![](https://miro.medium.com/max/2340/1*Fw-ehcNBR9byHtho-Rxbtw.gif)

# %% [markdown]
# ### 패딩(Padding)
#
# - 합성곱 연산을 수행하기 전에 입력 데이터 주변을 0과 같은 특정값으로 채우기도 함
# - 이러한 과정을 패딩(Padding)이라 함
# - 패딩은 주로 출력 크기를 조정할 목적으로 사용함
# - 그러한 이유는 합성곱 연산을 거칠때마다 크기가 작아지면 어느 시점에서는 출력의 크기가 1이 되어버리는 사태가 발생하므로 더이상 합성곱 연산을 할 수 없게 됨
#
# ![](https://blogfiles.pstatic.net/MjAxODA5MjRfMjcz/MDAxNTM3Nzc3MDA5ODc1.vjDUmMFKoOuhbfzYGDGUgUKq0ewItej2BnHc-DJ8t-Eg.cqxDvBP9N9SSw_zYNAHVe32Yt-wyhaYcSmXf1BK6dI4g.PNG.ssdyka/fig_7-6.png?type=w2)

# %% [markdown]
# > 이미지가 움직이지 않는다면 : http://deeplearning.net/software/theano_versions/dev/_images/arbitrary_padding_no_strides.gif
#
# ![](http://deeplearning.net/software/theano_versions/dev/_images/arbitrary_padding_no_strides.gif)

# %% [markdown]
# ### 스트라이드(Stride)
#
# - 필터를 적용하는 위치의 간격을 스트라이드(stride)라 함
#
# ![](https://blogfiles.pstatic.net/MjAxODA5MjRfMTg2/MDAxNTM3Nzc3MDEwNDA4.YiiyF_d9Q9Ok3qC7-pUv-foixY0jwZji-vPifOaBoHcg.ZkaPdzqtjq_obB4jl47HcJUfW99oV8wmH-AOD7KojScg.PNG.ssdyka/fig_7-7.png?type=w2)

# %% [markdown]
# ![](https://i.stack.imgur.com/ptDPZ.gif)

# %% [markdown]
# ### 특징 맵의 크기 계산하기
#
# - 입력 크기를 $(H,W)$, 필터 크기를 $(FH,FW)$, 출력 크기를 $(OH,OW)$, 패딩을 $P$, 스트라이드를 $S$라 했을 때,
#
# <br>
#
# $$ OH = \frac{H + 2P - FH}{S} + 1 $$
#
# $$ OW = \frac{H + 2P - FW}{S} + 1 $$

# %% [markdown]
# > 예시1
# > 입력: (4,4), 패딩: 1, 스트라이드: 1, 필터: (3,3)
#
# $$ OH = \frac{4 + 2\times1 - 3}{1} + 1 = 4$$
#
# $$ OW = \frac{4 + 2\times1 - 3}{1} + 1 = 4$$

# %% [markdown]
# > 예시2
# > 입력: (7,7), 패딩: 0, 스트라이드: 2, 필터: (3,3)
#
# $$ OH = \frac{7 + 2\times0 - 3}{1} + 1 = 3$$
#
# $$ OW = \frac{7 + 2\times0 - 3}{1} + 1 = 3$$

# %% [markdown]
# > 예시3
# > 입력: (28,31), 패딩: 2, 스트라이드: 3, 필터: (5,5)
#
# $$ OH = \frac{28 + 2\times2 - 5}{3} + 1 = 10$$
#
# $$ OW = \frac{31 + 2\times2 - 5}{3} + 1 = 11$$

# %% [markdown]
# > 항상 식의 결과가 정수로 나눠떨어지는 값이어야 한다는 점에 주의하자!
# > 출력 크기가 정수가 아니면 오류를 내는 등의 대응으로

# %% [markdown]
# ### 3차원 데이터의 합성곱 연산

# %% [markdown]
# - 사실 지금까지는 2차원 데이터를 다뤘음
# - 이미지의 경우, 채널 방향(RGB)으로 특징맵이 늘어났음
# - 쉽게 말해서, RGB와 같은 각각의 채널에 대해서 특징맵을 만들어줘야 함
# - 채널쪽으로 특징 맵이 여러개 있다면 입력 데이터와 필터의 합성곱 연산을 채널마다 수행하고, 그 결과를 더해서 하나의 출력으로 얻음
#
# ![](https://blogfiles.pstatic.net/MjAxODA5MjRfMTQ1/MDAxNTM3Nzc5NzA1OTk0.5Fpc-eaA-mPdCJI2OBwfnAu0C52n-cCD-GDsTIrpltgg.4VxJP7rFwW9ME53yMIYGHEvZe7xCNohBlGPPA_sv45Yg.PNG.ssdyka/fig_7-8.png?type=w2)
#
# > 3차원 데이터 합성곱 연산의 계산 순서
#
# ![](https://blogfiles.pstatic.net/MjAxODA5MjRfMzQg/MDAxNTM3Nzc5NzA2NDk4.S-xQzWJQii5KOBofxUDIK-7S8E3i3WlHCNtU4PPu-K4g.-b8icRMDh8BBt8nIxA-_Jq4TP0RGRanqGpDQI6x0wtUg.PNG.ssdyka/fig_7-9.png?type=w2)

# %% [markdown]
# > 주의해야할 점은 <font color ='red'>입력 데이터의 채널수</font>와 <font color ='red'>필터의 채널 수</font>가 같아야 한다는 점
# > 즉, 채널이 3개나 있는데 필터 2개로 3차원 합성곱 연산을 수행할 순 없음!

# %% [markdown]
# ![](https://www.cntk.ai/jup/cntk103d_conv2d_final.gif)

# %% [markdown]
# ![](https://www.researchgate.net/profile/Santhiya_Rajan/post/How_will_channels_RGB_effect_convolutional_neural_network/attachment/5c67b72d3843b0544e664e12/AS%3A726829115666434%401550300973344/download/cnn_1.gif)

# %% [markdown]
# ### 블록으로 생각하기 ⇒ 배치가 1일 때

# %% [markdown]
# - 쉽게 이해하려면 합성곱 연산은 데이터와 필터를 하나의 직육면체 블록이라고 생각하자
#
# <center> 3차원 데이터를 다차원 배열로 나타날 때의 순서는 <br> <font color='red'>$ (채널^{channel}, 높이^{height}, 너비^{width}) $</font> 순서로 씀 </center>
#
# - 예를 들면, 채널 수 $C$, 높이 $H$, 너비 $W$인 데이터의 형상은 $(C,H,W)$로 쓸 수 있음
# - 필터도 동일하게 $(C,FH,FW)$ 와 같은 같은 순서로 씀
#
# ![](https://t1.daumcdn.net/cfile/tistory/99CBDA375BA49AC720)

# %% [markdown]
# > 합성곱 연산의 출력으로 다수의 채널을 내보내려면 어떻게 해야할까?
# > 그 답은 **필터(가중치)를 여러개 사용**하는 것!
#
# ![](https://t1.daumcdn.net/cfile/tistory/99BB44335BA49AC71D)
#
# - 위와 같이 필터 $N$개를 적용하면 출력 맵도 $FN$개가 생성됨
# - 그 결과는 $(FN, OH, OW)$인 블록이 완성됨!

# %% [markdown]
# - 이렇듯, 합성곱 연산에서는 필터의 수($FN$)도 고려해야 함
# - 필터의 가중치 데이터는 4차원 데이터이며, **(출력 채널 수, 입력 채널 수, 높이, 너비)** 순으로 쓰임

# %% [markdown]
# ### 배치처리
#
# <center> 배치까지 적용된 데이터의 순서는 다음과 같다 <br> <font color='red'>$ (데이터수^{batch size},채널^{channel}, 높이^{height}, 너비^{width}) $</font> </center>
#
# > 주의할 점은 4차원 데이터가 하나 흐를 때마다 데이터 N개에 대한 합성곱 연산이 이뤄진다는 점
# 즉 N회 분의 처리를 한번에 수행하는 것
#
# ![](https://t1.daumcdn.net/cfile/tistory/997C864A5BA49AC72E)

# %% [markdown]
# ---
#
# ## 풀링 계층 (p240)
#
# - 풀링(Pooling): 세로/가로 방향의 공간을 줄이는 연산
#
# ![](https://2.bp.blogspot.com/-iiChU17hvk4/W9GFB7PDuiI/AAAAAAAAAKM/QozDW14qtkQ1270dA30dfQr6gCg6G9MAgCLcBGAs/s1600/12.png)
#
# - 위와 같은 방법을 최대 풀링(max pooling)이라고 함
# - 대상 영역에서 가장 큰 최댓값을 구하는 연산
# - 보통의 경우, 풀링의 윈도우 크기와 스트라이드는 같은 값으로 설정하는 것이 일반적임! 즉, 겹치지 않게 한다는 것!

# %% [markdown]
# ![](https://mlnotebook.github.io/img/CNN/poolfig.gif)

# %% [markdown]
# ### 풀링 계층의 특징
#
# #### 학습해야 할 매개변수가 없다
# - 합성곱 계층과 달리 학습해야 할 매개변수가 없음
#
# #### 채널 수가 변하지 않는다
# - 풀링 연산은 입력 데이터의 채널 수 그대로 출력 데이터로 내보냄
# - 채널마다 독립적으로 계산함
# ![](https://t1.daumcdn.net/cfile/tistory/9939CB505C20A95303)
#
# #### 입력의 변화에 영향을 적게 받는다(강건하다)
# - 입력 데이터가 조금 변해도 풀링의 결과가 잘 변하지 않음
# ![](https://t1.daumcdn.net/cfile/tistory/994E1A4B5C20A97013)

# %% [markdown]
# ---
#
# ## 합성곱/풀링 계층 구현하기 (p242)
#
# - 합성곱 계층과 풀링 계층 동일하게 `forward`와 `backward` 메서드를 추가하여 모듈로 이용 가능

# %% [markdown]
# ### 4차원 배열

# %%
x = np.random.rand(10,1,28,28)
x.shape
# Out:
# (10, 1, 28, 28)

# %%
x[0].shape # 첫번째 이미지 데이터
# Out:
# (1, 28, 28)

# %%
x[0,0] # x[0][0] : 첫 채널의 공간 데이터에 접근
# Out:
# array([[2.11205379e-01, 1.46614751e-01, 6.17007989e-01, 9.73454577e-01,
#         7.53245119e-01, 7.21610131e-01, 3.75137307e-01, 8.79777601e-01,
#         5.59150881e-01, 2.48040497e-01, 2.85396731e-01, 1.44080806e-01,
#         7.46136213e-01, 7.96344835e-01, 6.33222065e-01, 2.07448634e-02,
#         9.36945635e-02, 9.98099883e-01, 9.97521212e-02, 2.76777213e-01,
#         7.41710061e-01, 5.79888789e-01, 8.89575634e-01, 6.11291110e-01,
#         9.04867763e-01, 2.16312997e-01, 4.12240045e-01, 8.76965828e-01],
#        [5.71816667e-01, 5.03556805e-01, 9.65757548e-01, 6.73707070e-01,
#         7.61978109e-01, 7.37790344e-02, 3.07928583e-01, 7.66274543e-01,
#         1.31831235e-01, 8.06193075e-01, 4.97471008e-01, 4.59519212e-01,
#         7.63342622e-01, 8.40317283e-01, 1.76036323e-01, 5.68629643e-01,
#         5.05170166e-01, 1.88719977e-01, 8.00032665e-01, 1.45616384e-02,
#         8.22109719e-01, 4.94344365e-02, 5.13424684e-01, 2.26496165e-01,
# ...

# %% [markdown]
# ### im2col로 데이터 전개하기

# %% [markdown]
# - 합성곱 연산을 정직하게 구현하려면 for문을 중첩해야함 ⇒ 솔직히 너무 귀찮
# - `im2col`이라는 함수를 통해서 합성곱 구현을 쉽게 구현하는 트릭을 써보자
#
# > `im2col`은 입력 데이터를 필터링(가중치 계산)하기 좋게 전개하는(펼치는) 함수
# 아래 그림과 같이 3차원 입력 뎅이터에 im2col을 적용하면 2차원 행렬로 바뀜, 즉 배치 안의 데이터 수까지 포함한 4차원 데이터를 2차원으로 변환
#
# <img src="https://petewarden.files.wordpress.com/2015/04/im2col_corrected.png" width=400>
#
# - im2col은 필터링하기 좋게 입력 데이터를 전개
# - 입력 데이터에서 필터를 적용하는 영역(3차원 블록)을 한줄로 늘어놓음
# - 이러한 전개를 필터를 적용하는 모든 영역에서 수행하는게 im2col임

# %% [markdown]
# ![](https://t1.daumcdn.net/cfile/tistory/99F49B495BA49CE71C)

# %% [markdown]
# ![](http://nmhkahn.github.io/assets/CNN-Practice/im2col.png)

# %% [markdown]
# ![](https://camo.qiitausercontent.com/5e700263bb2d347a320d8e2821fc8e368c924d5c/68747470733a2f2f71696974612d696d6167652d73746f72652e73332e616d617a6f6e6177732e636f6d2f302f3239323230372f34323336363931612d333135662d646238652d323735382d6532333837626465393631612e676966)
#
# > 필터가 적용되는 영역은 대부분 겹치기 때문에 **im2col로 전개한 후의 원소 수가 원래 블록의 원소 수보다 많아짐**
# im2col을 사용하면 `메모리를 더 많이 소비하는 단점`이 있음, 하지만 그럼에도 불구하고 컴퓨터는 큰 행렬을 묶어 계산하는데 탁월

# %% [markdown]
# ![](http://xuhan.me/uploads/im2col.png)

# %% [markdown]
# ```python
# # im2col 함수의 인터페이스
# def im2col(input_data, filter_h, filter_w, stride=1, pad=0):
#     """다수의 이미지를 입력받아 2차원 배열로 변환한다(평탄화).
#
#     Parameters
#     ----------
#     input_data : 4차원 배열 형태의 입력 데이터(이미지 수, 채널 수, 높이, 너비)
#     filter_h : 필터의 높이
#     filter_w : 필터의 너비
#     stride : 스트라이드
#     pad : 패딩
#
#     Returns
#     -------
#     col : 2차원 배열
#     """
#     N, C, H, W = input_data.shape
#     out_h = (H + 2*pad - filter_h)//stride + 1
#     out_w = (W + 2*pad - filter_w)//stride + 1
#
#     img = np.pad(input_data, [(0,0), (0,0), (pad, pad), (pad, pad)], 'constant')
#     col = np.zeros((N, C, filter_h, filter_w, out_h, out_w))
#
#     for y in range(filter_h):
#         y_max = y + stride*out_h
#         for x in range(filter_w):
#             x_max = x + stride*out_w
#             col[:, :, y, x, :, :] = img[:, :, y:y_max:stride, x:x_max:stride]
#
#     col = col.transpose(0, 4, 5, 1, 2, 3).reshape(N*out_h*out_w, -1)
#     return col
# ```

# %%
x1 = np.random.rand(1,3,7,7) # 데이터 수, 채널 수, 높이, 너비
x1.shape
# Out:
# (1, 3, 7, 7)

# %%
col1 = im2col(x1, 5, 5, stride=1, pad=0)
col1.shape
# Out:
# (9, 75)

# %%
x2 = np.random.rand(10,3,7,7) # 데이터 수, 채널 수, 높이, 너비
x2.shape
# Out:
# (10, 3, 7, 7)

# %%
col2 = im2col(x2, 5, 5, stride=1, pad=0)
col2.shape
# Out:
# (90, 75)

# %% [markdown]
# ### 합성곱 계층 구현하기

# %% [markdown]
# ```python
# class Convolution:
#     def __init__(self, W, b, stride=1, pad=0):
#         self.W = W
#         self.b = b
#         self.stride = stride
#         self.pad = pad
#
#         # 중간 데이터（backward 시 사용）
#         self.x = None
#         self.col = None
#         self.col_W = None
#
#         # 가중치와 편향 매개변수의 기울기
#         self.dW = None
#         self.db = None
#
#     def forward(self, x):
#         FN, C, FH, FW = self.W.shape
#         N, C, H, W = x.shape
#         out_h = 1 + int((H + 2*self.pad - FH) / self.stride)
#         out_w = 1 + int((W + 2*self.pad - FW) / self.stride)
#
#         # 입력 데이터를 im2col 함수로 전개
#         # 이것 덕분에 완전연결 계층의 Affine 계층과 거의 똑같이 이후 구현가능
#         col = im2col(x, FH, FW, self.stride, self.pad)
#
#         # reshape 함수를 통해서 2차원 배열로 전개함
#         # 이를 통해서 다차원 배열의 원소 수가 변환 후에도 똑같이 유지
#         col_W = self.W.reshape(FN, -1).T
#
#         out = np.dot(col, col_W) + self.b
#         out = out.reshape(N, out_h, out_w, -1).transpose(0, 3, 1, 2) # 다차원 배열의 축 순서를 바꿔줌
#
#         self.x = x
#         self.col = col
#         self.col_W = col_W
#
#         return out
#
#     def backward(self, dout):
#         FN, C, FH, FW = self.W.shape
#         dout = dout.transpose(0,2,3,1).reshape(-1, FN)
#
#         self.db = np.sum(dout, axis=0)
#         self.dW = np.dot(self.col.T, dout)
#         self.dW = self.dW.transpose(1, 0).reshape(FN, C, FH, FW)
#
#         dcol = np.dot(dout, self.col_W.T)
#         dx = col2im(dcol, self.x.shape, FH, FW, self.stride, self.pad) # im2col과 반대인 함수인 col2im 함수
#
#         return dx
# ```

# %% [markdown]
# ### 풀링 계층 구현하기
#
# - im2col 함수를 토해서 입력 데이터를 전개
# - 채널 쪽이 독립적이라는 점이 합성곱 계층 때와 다른 점

# %% [markdown]
# ![](https://t1.daumcdn.net/cfile/tistory/992F044B5C4D422B02)
#
# > 위와 같이 전개한 후, 전개한 행렬에 대해서 행별 최댓값을 구하고 적절한 형상으로 바꿔주면 됨

# %% [markdown]
# > 풀링 계층은 3단계로 수행됨
# 1. 입력 데이터를 전개함
# 2. 행별 최댓값을 구함
# 3. 적절한 모양으로 성형

# %% [markdown]
# ![](https://t1.daumcdn.net/cfile/tistory/99C888485C4D425402)

# %% [markdown]
# ```python
# class Pooling:
#     def __init__(self, pool_h, pool_w, stride=1, pad=0):
#         self.pool_h = pool_h
#         self.pool_w = pool_w
#         self.stride = stride
#         self.pad = pad
#
#         self.x = None
#         self.arg_max = None
#
#     def forward(self, x):
#         N, C, H, W = x.shape
#         out_h = int(1 + (H - self.pool_h) / self.stride)
#         out_w = int(1 + (W - self.pool_w) / self.stride)
#
#         # 1단계 : 입력 데이터 전개
#         col = im2col(x, self.pool_h, self.pool_w, self.stride, self.pad)
#         col = col.reshape(-1, self.pool_h*self.pool_w)
#
#         # 2단계 : 행별 최댓값 구하기
#         arg_max = np.argmax(col, axis=1)
#         out = np.max(col, axis=1)
#
#         # 3단계 : 적절한 모양으로 바꾸기
#         out = out.reshape(N, out_h, out_w, C).transpose(0, 3, 1, 2)
#
#         self.x = x
#         self.arg_max = arg_max
#
#         return out
#
#     def backward(self, dout):
#         # ReLU 계층 구현할 때 사용한 max의 역전파를 참고 (5.5.1)
#         dout = dout.transpose(0, 2, 3, 1)
#
#         pool_size = self.pool_h * self.pool_w
#         dmax = np.zeros((dout.size, pool_size))
#         dmax[np.arange(self.arg_max.size), self.arg_max.flatten()] = dout.flatten()
#         dmax = dmax.reshape(dout.shape + (pool_size,))
#
#         dcol = dmax.reshape(dmax.shape[0] * dmax.shape[1] * dmax.shape[2], -1)
#         dx = col2im(dcol, self.x.shape, self.pool_h, self.pool_w, self.stride, self.pad)
#
#         return dx
#
# ```

# %% [markdown]
# ---
#
# ## CNN 구현하기 (p250)

# %% [markdown]
# ![](https://newtypeunion.files.wordpress.com/2017/07/ec8aa4ed81aceba6b0ec83b7-2017-07-16-ec98a4ed9b84-6-55-23.png?w=800)

# %%
class SimpleConvNet:
    """단순한 합성곱 신경망
    
    conv - relu - pool - affine - relu - affine - softmax
    
    Parameters
    ----------
    input_size : 입력 크기（MNIST의 경우엔 784）
    hidden_size_list : 각 은닉층의 뉴런 수를 담은 리스트（e.g. [100, 100, 100]）
    output_size : 출력 크기（MNIST의 경우엔 10）
    activation : 활성화 함수 - 'relu' 혹은 'sigmoid'
    weight_init_std : 가중치의 표준편차 지정（e.g. 0.01）
        'relu'나 'he'로 지정하면 'He 초깃값'으로 설정
        'sigmoid'나 'xavier'로 지정하면 'Xavier 초깃값'으로 설정
    """
    def __init__(self, input_dim=(1, 28, 28), 
                 conv_param={'filter_num':30, 'filter_size':5, 'pad':0, 'stride':1},
                 hidden_size=100, output_size=10, weight_init_std=0.01):
        filter_num = conv_param['filter_num']
        filter_size = conv_param['filter_size']
        filter_pad = conv_param['pad']
        filter_stride = conv_param['stride']
        input_size = input_dim[1]
        conv_output_size = (input_size - filter_size + 2*filter_pad) / filter_stride + 1
        pool_output_size = int(filter_num * (conv_output_size/2) * (conv_output_size/2))

        # 가중치 초기화
        self.params = {}
        self.params['W1'] = weight_init_std * \
                            np.random.randn(filter_num, input_dim[0], filter_size, filter_size)
        self.params['b1'] = np.zeros(filter_num)
        self.params['W2'] = weight_init_std * \
                            np.random.randn(pool_output_size, hidden_size)
        self.params['b2'] = np.zeros(hidden_size)
        self.params['W3'] = weight_init_std * \
                            np.random.randn(hidden_size, output_size)
        self.params['b3'] = np.zeros(output_size)

        # 계층 생성
        self.layers = OrderedDict()
        self.layers['Conv1'] = Convolution(self.params['W1'], self.params['b1'],
                                           conv_param['stride'], conv_param['pad'])
        self.layers['Relu1'] = Relu()
        self.layers['Pool1'] = Pooling(pool_h=2, pool_w=2, stride=2)
        self.layers['Affine1'] = Affine(self.params['W2'], self.params['b2'])
        self.layers['Relu2'] = Relu()
        self.layers['Affine2'] = Affine(self.params['W3'], self.params['b3'])

        self.last_layer = SoftmaxWithLoss()

    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)

        return x

    def loss(self, x, t):
        """손실 함수를 구한다.

        Parameters
        ----------
        x : 입력 데이터
        t : 정답 레이블
        """
        y = self.predict(x)
        return self.last_layer.forward(y, t)

    def accuracy(self, x, t, batch_size=100):
        if t.ndim != 1 : t = np.argmax(t, axis=1)
        
        acc = 0.0
        
        for i in range(int(x.shape[0] / batch_size)):
            tx = x[i*batch_size:(i+1)*batch_size]
            tt = t[i*batch_size:(i+1)*batch_size]
            y = self.predict(tx)
            y = np.argmax(y, axis=1)
            acc += np.sum(y == tt) 
        
        return acc / x.shape[0]

    def numerical_gradient(self, x, t):
        """기울기를 구한다（수치미분）.

        Parameters
        ----------
        x : 입력 데이터
        t : 정답 레이블

        Returns
        -------
        각 층의 기울기를 담은 사전(dictionary) 변수
            grads['W1']、grads['W2']、... 각 층의 가중치
            grads['b1']、grads['b2']、... 각 층의 편향
        """
        loss_w = lambda w: self.loss(x, t)

        grads = {}
        for idx in (1, 2, 3):
            grads['W' + str(idx)] = numerical_gradient(loss_w, self.params['W' + str(idx)])
            grads['b' + str(idx)] = numerical_gradient(loss_w, self.params['b' + str(idx)])

        return grads

    def gradient(self, x, t):
        """기울기를 구한다(오차역전파법).

        Parameters
        ----------
        x : 입력 데이터
        t : 정답 레이블

        Returns
        -------
        각 층의 기울기를 담은 사전(dictionary) 변수
            grads['W1']、grads['W2']、... 각 층의 가중치
            grads['b1']、grads['b2']、... 각 층의 편향
        """
        # forward
        self.loss(x, t)

        # backward
        dout = 1
        dout = self.last_layer.backward(dout)

        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 결과 저장
        grads = {}
        grads['W1'], grads['b1'] = self.layers['Conv1'].dW, self.layers['Conv1'].db
        grads['W2'], grads['b2'] = self.layers['Affine1'].dW, self.layers['Affine1'].db
        grads['W3'], grads['b3'] = self.layers['Affine2'].dW, self.layers['Affine2'].db

        return grads
        
    def save_params(self, file_name="params.pkl"):
        params = {}
        for key, val in self.params.items():
            params[key] = val
        with open(file_name, 'wb') as f:
            pickle.dump(params, f)

    def load_params(self, file_name="params.pkl"):
        with open(file_name, 'rb') as f:
            params = pickle.load(f)
        for key, val in params.items():
            self.params[key] = val

        for i, key in enumerate(['Conv1', 'Affine1', 'Affine2']):
            self.layers[key].W = self.params['W' + str(i+1)]
            self.layers[key].b = self.params['b' + str(i+1)]

# %% [markdown]
# ### SimpleConvNet으로 MNIST 데이터셋 학습하기

# %%
# 데이터 읽기
(x_train, t_train), (x_test, t_test) = load_mnist(flatten=False)

# 시간이 오래 걸릴 경우 데이터를 줄인다.
x_train, t_train = x_train[:5000], t_train[:5000]
x_test, t_test = x_test[:1000], t_test[:1000]

# %%
max_epochs = 10

# %%
network = SimpleConvNet(input_dim=(1,28,28), 
                        conv_param = {'filter_num': 30, 'filter_size': 5, 'pad': 0, 'stride': 1},
                        hidden_size=100,
                        output_size=10,
                        weight_init_std=0.01)

# %%
trainer = Trainer(network,
                  x_train, t_train, x_test, t_test,
                  epochs=max_epochs,
                  mini_batch_size=100,
                  optimizer='Adam',
                  optimizer_param={'lr': 0.001},
                  evaluate_sample_num_per_epoch=1000,
                  verbose=True)

# %%
trainer.train() # 직접 학습해보자
# Out:
# train loss:2.299641688619
# === epoch:1, train acc:0.289, test acc:0.233 ===
# train loss:2.2965296880188393
# train loss:2.2886973524046623
# train loss:2.2838123189291157
# train loss:2.2732614620884837
# train loss:2.259824051982804
# train loss:2.2516402869170755
# train loss:2.2186890268161696
# train loss:2.1759997643195588
# train loss:2.170258829786526
# train loss:2.1239669917719417
# train loss:2.071281455543205
# train loss:1.9949998045715847
# train loss:1.9314951490015349
# train loss:1.8753955684377397
# train loss:1.8693423515257444
# train loss:1.8084644193504646
# train loss:1.6802142081999616
# train loss:1.5816821750374825
# train loss:1.5374629739539976
# train loss:1.4385411606777976
# train loss:1.400293717076586
# train loss:1.2462128992476424
# train loss:1.3355788351007951
# train loss:1.2349562923956994
# train loss:1.0098032707093583
# train loss:0.9505758823323613
# train loss:0.8995696992426713
# train loss:0.8738271594384074
# ...

# %%
# 매개변수 보존
network.save_params("ch07/params.pkl")
print("Saved Network Parameters!")
# Out:
# Saved Network Parameters!

# %%
# 그래프 그리기
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, trainer.train_acc_list, marker='o', label='train', markevery=2)
plt.plot(x, trainer.test_acc_list, marker='s', label='test', markevery=2)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ---
#
# ## CNN 시각화하기 (p254)
#
# - CNN을 구성하는 합성곱 계층은 입력으로 받은 이미지 데이터에서 무엇을 보고 있는걸까?

# %% [markdown]
# ### 첫번째 층의 가중치 시각화하기
#
#
# #### MNIST 에서 학습한 필터 확인해보기
# - 1번째 층의 합성곱 계층의 가중치 형상 : (30, 1, 5, 5)
# - 채널이 1개이기 때문에 회색조 이미지로 시각화 가능함!
# - 필터를 이미지로 나타내보자

# %%
def filter_show(filters, nx=8, margin=3, scale=10):
    """
    c.f. https://gist.github.com/aidiary/07d530d5e08011832b12#file-draw_weight-py
    """
    FN, C, FH, FW = filters.shape
    ny = int(np.ceil(FN / nx))

    fig = plt.figure()
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(FN):
        ax = fig.add_subplot(ny, nx, i+1, xticks=[], yticks=[])
        ax.imshow(filters[i, 0], cmap=plt.cm.gray_r, interpolation='nearest')
    plt.show()

# %%
network = SimpleConvNet()

# %%
# 학습 전 필터(가중치)
# 무작위(랜덤) 초기화 후의 가중치
filter_show(network.params['W1'])

# %%
# 학습 후 필터(가중치)
network.load_params("ch07/params.pkl")
filter_show(network.params['W1'])

# %% [markdown]
# - 학습 전 필터
#     - 무작위로 초기화 되어 있어 흑백의 정도에 규칙성이 없음
# - 학습 후 필터
#     - 규칙성이 어느 정도 있는 이미지
#     - 흰색에서 검은색으로 점차 변화하는 필터
#     - 덩어리가 진 필터 등등
#
# - 합성곱 계층의 필터는 에지나 블롭 등의 원시적인 정보를 추출가능

# %% [markdown]
# ![](https://t1.daumcdn.net/cfile/tistory/224E1641583ED6AC34)
#
# - 필터는 말 그대로 이미지에서 필터와 비슷한 패턴을 찾는 과정이라고 생각하면 된다
# - 그래서 여러개의 필터가 있을수록 다양한 정보를 추출할 수 있음

# %% [markdown]
# #### Lena 이미지로 필터 확인해보기

# %%
network = SimpleConvNet(input_dim=(1,28,28), 
                        conv_param = {'filter_num':30, 'filter_size':5, 'pad':0, 'stride':1},
                        hidden_size=100, output_size=10, weight_init_std=0.01)

# %%
def filter_show(filters, nx=4, show_num=16):
    """
    c.f. https://gist.github.com/aidiary/07d530d5e08011832b12#file-draw_weight-py
    """
    FN, C, FH, FW = filters.shape
    ny = int(np.ceil(show_num / nx))

    fig = plt.figure()
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(show_num):
        ax = fig.add_subplot(4, 4, i+1, xticks=[], yticks=[])
        ax.imshow(filters[i, 0], cmap=plt.cm.gray_r, interpolation='nearest')

# %%
# 학습된 가중치
network.load_params("ch07/params.pkl")
filter_show(network.params['W1'], 16)

# %%
img = imread('dataset/lena_gray.png')
img = img.reshape(1, 1, *img.shape)

fig = plt.figure(figsize=(12,12))

w_idx = 1

for i in range(16):
    w = network.params['W1'][i]
    b = 0  # network.params['b1'][i]

    w = w.reshape(1, *w.shape)
    #b = b.reshape(1, *b.shape)
    conv_layer = Convolution(w, b) 
    out = conv_layer.forward(img)
    out = out.reshape(out.shape[2], out.shape[3])
    
    ax = fig.add_subplot(4, 4, i+1, xticks=[], yticks=[])
    ax.imshow(out, cmap=plt.cm.gray_r, interpolation='nearest')

plt.show()

# %% [markdown]
# ### 층 깊이에 따른 추출 정보 변화

# %% [markdown]
# ![](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=http%3A%2F%2Fcfile5.uf.tistory.com%2Fimage%2F990A613B5BC97E7D1B7187)
#
# > 계층이 깊어질수록 추출되는 정보, 즉 강하게 반응하는 뉴런은 더 추상화된다는 것을 알 수 있음

# %% [markdown]
# - 합성곱 계층을 여러겹 쌓으면, 층이 깊어지면서 더 복잡하고 추상화된 정보가 추출된다는 점
# - 처음 층은 단순한 에지에 반응하고, 이어서 텍스처에 반응하고, 더 복잡한 사물의 일부에 반응하도록 변화함
# - 층이 기어지면서 뉴런이 반응하는 대상이 단순한 모양에서 고급정보로 변화
# - 사물의 의미를 이해하도록 변화함

# %% [markdown]
# ---
#
# ## 대표적인 CNN (p257)

# %% [markdown]
# ### LeNet
#
# ![](https://miro.medium.com/max/850/1*AwJZkWLKabIicUPzSN6KCg.png)

# %% [markdown]
# - LeNet과 현재 흔히 알고 있는 CNN을 비교하면 몇가지 차이점 존재
#     - 활성화 함수의 사용 여부
#         - LeNet : Sigmoid
#         - 현재 : ReLU
#     - 데이터의 크기를 줄이는 방법
#         - LeNet : SubSampling
#         - 현재 : MaxPooling

# %% [markdown]
# ### AlexNet
#
# ![](https://www.researchgate.net/profile/Jaime_Gallego2/publication/318168077/figure/fig1/AS:578190894927872@1514862859810/AlexNet-CNN-architecture-layers.png)

# %% [markdown]
# - AlexNet은 딥러닝 열풍을 일으키는데 큰 역할
# - 합성곱 계층과 풀링 계층을 거듭하며 마지막으로 완전연결 계층을 거쳐 결과를 출력
# - LeNet과의 차이점
#     - 활성화 함수로 ReLU
#     - LRN(Local Response Normalizatoin)이라는 국소적 정규활르 실시하는 계층을 이용
#     - 드롭아웃(Dropout) 계층 사용

# %% [markdown]
# ---
#
# ## 7장 정리 (p259)
#
# > 참고 : [WegraLee GitHub](https://github.com/WegraLee/deep-learning-from-scratch/blob/master/ch07/README.md)
#
# * CNN은 지금까지의 완전연결 계층 네트워크에 합성곱 계층과 풀링 계층을 새로 추가한다.
# * 합성곱 계층과 풀링 계층은 im2col (이미지를 행렬로 전개하는 함수)을 이용하면 간단하고 효율적으로 구현할 수 있다.
# * CNN을 시각화해보면 계층이 깊어질수록 고급 정보가 추출되는 모습을 확인할 수 있다.
# * 대표적인 CNN에는 LeNet과 AlexNet이 있다.
# * 딥러닝의 발전에는 빅 데이터와 GPU가 크게 기여했다.

# %% [markdown]
# ---
#
# ## 참고
# - 밑바닥부터 시작하는 딥러닝 GitHub : https://github.com/WegraLee/deep-learning-from-scratch
# - Mathjax 웹 수식 : https://www.codecogs.com/latex/eqneditor.php / http://detexify.kirelabs.org/classify.html
# - 네이버 블로그 : https://blog.naver.com/PostView.nhn?blogId=ssdyka&logNo=221364894122&categoryNo=0&parentCategoryNo=0&viewDate=&currentPage=1&postListTopCurrentPage=1&from=postView&userTopListOpen=true&userTopListCount=5&userTopListManageOpen=false&userTopListCurrentPage=1
